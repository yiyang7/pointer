# %%
from os import listdir
from os.path import isfile, join
from sumeval.metrics.rouge import RougeCalculator
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %% [markdown]
# # example

# %%
from sumeval.metrics.rouge import RougeCalculator
rouge = RougeCalculator(stopwords=True, lang="en")

rouge_1 = rouge.rouge_n(
            summary="I went to the Mars from my living town.",
            references="I went to Mars",
            n=1)

rouge_2 = rouge.rouge_n(
            summary="I went to the Mars from my living town.",
            references=["I went to Mars", "It's my living town"],
            n=2)

rouge_l = rouge.rouge_l(
            summary="I went to the Mars from my living town.",
            references=["I went to Mars", "It's my living town"])

# You need spaCy to calculate ROUGE-BE

rouge_be = rouge.rouge_be(
            summary="I went to the Mars from my living town.",
            references=["I went to Mars", "It's my living town"])

print("ROUGE-1: {}, ROUGE-2: {}, ROUGE-L: {}, ROUGE-BE: {}".format(
    rouge_1, rouge_2, rouge_l, rouge_be
).replace(", ", "\n"))
# Out:
# ROUGE-1: 0.5
# ROUGE-2: 0.4
# ROUGE-L: 0.6666666666666666
# ROUGE-BE: 0.4

# %%
# relationship small dataset
path_pre = "/home/ubuntu/cs224u/processed_relationships/baseline"
ref_path = path_pre + '/reference'
reference_files = [f for f in listdir(ref_path) if isfile(join(ref_path, f))]
dec_path = path_pre + '/decoded'
decoded_files = [f for f in listdir(dec_path) if isfile(join(dec_path, f))]

# %%
reference_files
# Out:
# ['t3_4bcuhi_reference.txt',
#  't3_3yzftu_reference.txt',
#  '6ejvy9_reference.txt',
#  'd5axozy_reference.txt',
#  't3_29tth3_reference.txt',
#  'di3h5hh_reference.txt',
#  'd62d0ho_reference.txt',
#  '64tr5t_reference.txt',
#  't3_1udtww_reference.txt']

# %%
def computeRougeScore(path_pre, alpha_input = 0.5, consider_first = 0, if_rouge_be = False, 
                      random_test = True,
                      first_str_in_ref = 0, print_progress = False, print_result = False,
                      confidence_level = 0.90,
                     ref_folder = '/reference/', decode_folder = '/decoded/', 
                     look_at_subred = None, file_to_subred_mapping = None):
    '''
    input: a working directory indicate where the reference and decode files are
    '''
    # setup working directory
    ref_path = path_pre + ref_folder
    dec_path = path_pre + decode_folder
    
    if look_at_subred is not None and file_to_subred_mapping is not None :
        reference_files = [f for f in listdir(ref_path) if isfile(join(ref_path, f)) and 
                          file_to_subred_mapping[f[:6]] == look_at_subred]
        reference_files.sort()
        #reference_files = reference_files[:5000]: to deal with the large AskReddit Dataset
        decoded_files = [f for f in listdir(dec_path) if isfile(join(dec_path, f)) and 
                          file_to_subred_mapping[f[:6]] == look_at_subred]
        decoded_files.sort()
        #decoded_files = decoded_files[:5000]: to deal with the large AskReddit Dataset
    else:
        reference_files = [f for f in listdir(ref_path) if isfile(join(ref_path, f))]
        reference_files.sort()
        #reference_files = reference_files[:5000]: to deal with the large AskReddit Dataset
        decoded_files = [f for f in listdir(dec_path) if isfile(join(dec_path, f))]
        decoded_files.sort()
        #decoded_files = decoded_files[:5000]: to deal with the large AskReddit Dataset
    
    
    rouge = RougeCalculator(stopwords=False, lang="en")
#     if consider_first:
#         reference_files = reference_files[:consider_first]
#         decoded_files = decoded_files[:consider_first]
    num_file = len(reference_files)
    
    # select random(or first) part of the data 
    if random_test and consider_first > 0:
        chosen_index = np.random.choice(num_file, consider_first, replace = False)
    elif consider_first > 0:
        chosen_index = np.arange(consider_first)
    else:
        chosen_index = np.arange(num_file)
    
    num_file = len(chosen_index)
    
    rouge_1 = np.zeros(num_file)
    rouge_2 = np.zeros(num_file)
    rouge_l = np.zeros(num_file)
    rouge_be = np.zeros(num_file)
    
    
    for i, indx in enumerate(chosen_index):
        
        if i % 500 == 0 and print_progress:
            print('calculating i, finished', i/num_file)
            
        f_ref = open(ref_path + reference_files[indx], 'r').read()
#         print(f_ref[:10])
        if first_str_in_ref:
            f_ref = f_ref[:int(len(f_ref) * first_str_in_ref)]
        f_decode = open( dec_path + decoded_files[indx], 'r').read()
#         print(reference_files[i], decoded_files[i])
        rouge_1[i] = rouge.rouge_n(
            summary=f_decode,
            references=f_ref,
            n=1,alpha = alpha_input)

        rouge_2[i] = rouge.rouge_n(
            summary=f_decode,
            references=f_ref,
            n=2, alpha = alpha_input)

        rouge_l[i] = rouge.rouge_l(
            summary=f_decode,
            references=f_ref,alpha = alpha_input)
        
        if if_rouge_be:
            rouge_be[i] = rouge.rouge_be(
                summary=f_decode,
                references=f_ref,alpha = alpha_input)

    rouge_1_average = np.mean(rouge_1)    
    rouge_2_average = np.mean(rouge_2)    
    rouge_l_average = np.mean(rouge_l)
    
    def half_interval(data):
        # return the half CI interval length with given confidence level
        return norm.ppf(confidence_level) * np.std(data) / np.sqrt(len(data))
#         return (np.quantile(data, 0.8) - np.quantile(data, 0.2))/2
    
    rouge_1_half_CI = half_interval(rouge_1)    
    rouge_2_half_CI = half_interval(rouge_2)    
    rouge_l_half_CI = half_interval(rouge_l)
        
    if print_result:
        print("in total ", len(chosen_index), "examples")
        print("rouge_1_average score:", rouge_1_average, rouge_1_half_CI)
        print("rouge_2_average score:", rouge_2_average, rouge_2_half_CI)
        print("rouge_l_average score:", rouge_l_average, rouge_l_half_CI)
    
    if if_rouge_be:
        rouge_be_average = np.mean(rouge_be)
        print("rouge_be_average score:", rouge_be_average)   
        return [rouge_1_average, rouge_2_average, rouge_l_average, rouge_be_average]
    
    return [rouge_1_average, rouge_2_average, rouge_l_average]

# %%
# pretrained on relationships

path_pre = './log/big_multi_pvocab_combine2_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-596_cov_init'

computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, print_result=True)
# computeRougeScore(path_pre, alpha_input = 0.99,  consider_first=1000, 
#                   ref_folder = '/content/', decode_folder = '/decoded/',
#                  print_result=True)
# Out:
# in total  37 examples
# rouge_1_average score: 0.10620824259016817 0.014049095428767228
# rouge_2_average score: 0.00421065410104504 0.002569839199976943
# rouge_l_average score: 0.0826712258835274 0.010676529926174162
# [0.10620824259016817, 0.00421065410104504, 0.0826712258835274]

# %%
# pretrained on relationships

path_pre = './log/pretrained_relationships_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238410_cov_init_cov_init'

computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, print_result=True)
# computeRougeScore(path_pre, alpha_input = 0.99,  consider_first=1000, 
#                   ref_folder = '/content/', decode_folder = '/decoded/',
#                  print_result=True)
# Out:
# in total  119 examples
# rouge_1_average score: 0.15243363615360483 0.07639610389610388
# rouge_2_average score: 0.02640599118214271 0.02544628367413178
# rouge_l_average score: 0.11181573118002303 0.049482538064730845
# [0.15243363615360483, 0.02640599118214271, 0.11181573118002303]

# %%
in total  119 examples
rouge_1_average score: 0.15243363615360483 0.010535262266423017
rouge_2_average score: 0.02640599118214271 0.00430942747738635
rouge_l_average score: 0.11181573118002303 0.006939508221985978

# %%
# full tuned on relationships

path_pre = './log/pretrained_full_tune_relationships_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238965_cov_init'

computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, print_result=True)
# computeRougeScore(path_pre, alpha_input = 0.99,  consider_first=1000, 
#                   ref_folder = '/reference/', decode_folder = '/decoded/',
#                  print_result=True)
# Out:
# in total  119 examples
# rouge_1_average score: 0.20289855193474882 0.010637316340643016
# rouge_2_average score: 0.05666682703407628 0.007896286441702155
# rouge_l_average score: 0.1569817754930441 0.00877156643846429
# [0.20289855193474882, 0.05666682703407628, 0.1569817754930441]

# %%
# fine tuned on relationships

path_pre = './log/pretrained_fine_tune_relationships_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238949_cov_init'

computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, print_result=True)
# computeRougeScore(path_pre, alpha_input = 0.99,  consider_first=1000, 
#                   ref_folder = '/reference/', decode_folder = '/decoded/',
#                  print_result=True)
# Out:
# in total  119 examples
# rouge_1_average score: 0.210399892937429 0.012350100982744165
# rouge_2_average score: 0.061066517631897736 0.007995787578539358
# rouge_l_average score: 0.16126166888240775 0.009082865177290917
# [0.210399892937429, 0.061066517631897736, 0.16126166888240775]

# %%
# pretrain v.s. full tune v.s. fine tune on relationship 1000
# pretrain
rouge_1_average score: 0.15243363615360483
rouge_2_average score: 0.02640599118214271
rouge_l_average score: 0.11181573118002303
    
# pretrain + full tune
rouge_1_average score: 0.20289855193474882
rouge_2_average score: 0.05666682703407628
rouge_l_average score: 0.1569817754930441
    
# pretrain + fine tune
rouge_1_average score: 0.210399892937429
rouge_2_average score: 0.061066517631897736
rouge_l_average score: 0.16126166888240775

# %%
# print the full tune and fine tune result for each subreddit, 10 epoch

# subreddit_names = ['relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
#                             'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

subreddit_names = ['legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
                            'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

# subreddit_names = ['nfl']

for sub in subreddit_names:
    path_pre = './log/full_tune_' + sub + '_exp/'
    subfolder_name = [d for d in listdir(path_pre) if d[:3] == 'dec'][0]
    path_pre += subfolder_name
    print(sub, 'full tune.....')
    computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, print_result=True)
    
    path_pre = './log/fine_tune_' + sub + '_exp/'
    subfolder_name = [d for d in listdir(path_pre) if d[:3] == 'dec'][0]
    path_pre += subfolder_name
    print(sub, 'fine tune.....')
    computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, print_result=True)
# Out:
# legaladvice full tune.....
# in total  118 examples
# rouge_1_average score: 0.19931211129935844 0.010984909688013769
# rouge_2_average score: 0.04133728864166904 0.006197554170236913
# rouge_l_average score: 0.14364021003229183 0.007799266627029889
# legaladvice fine tune.....
# in total  118 examples
# rouge_1_average score: 0.18969643502216854 0.010666744783501094
# rouge_2_average score: 0.03860472315092008 0.0059795952813765626
# rouge_l_average score: 0.1389372305281708 0.007885929386680458
# nfl full tune.....
# in total  111 examples
# rouge_1_average score: 0.13580159758110286 0.012212416787502766
# rouge_2_average score: 0.027642260153141886 0.005997207103997246
# rouge_l_average score: 0.10732908139194287 0.008875574360712396
# nfl fine tune.....
# in total  111 examples
# rouge_1_average score: 0.13996936713480254 0.012640923651108363
# rouge_2_average score: 0.02772071562859265 0.006480402934980252
# rouge_l_average score: 0.10895274407194087 0.009022661459099732
# pettyrevenge full tune.....
# in total  117 examples
# rouge_1_average score: 0.11950669289933086 0.00890802500690797
# rouge_2_average score: 0.021293555846445638 0.004288326536421477
# rouge_l_average score: 0.10091933957869188 0.007405510843457088
# pettyrevenge fine tune.....
# in total  117 examples
# rouge_1_average score: 0.1541941888563239 0.011632524181497532
# rouge_2_average score: 0.02937217967105411 0.00606292584205704
# rouge_l_average score: 0.12084503098145073 0.008952923236964946
# atheismbot full tune.....
# in total  119 examples
# rouge_1_average score: 0.2785232879477473 0.012384743706208417
# rouge_2_average score: 0.14125760800393564 0.011534088622378869
# rouge_l_average score: 0.24519860058062998 0.011901645112950058
# atheismbot fine tune.....
# in total  119 examples
# rouge_1_average score: 0.23245961421774772 0.013036631678740222
# rouge_2_average score: 0.11073754250857751 0.011109304875372924
# rouge_l_average score: 0.21434038382124435 0.012615771403510195
# ShouldIbuythisgame full tune.....
# in total  111 examples
# rouge_1_average score: 0.16485388550331725 0.011385065962215647
# rouge_2_average score: 0.051017403292215054 0.00708546369013112
# rouge_l_average score: 0.13260034943787513 0.009229477827489166
# ShouldIbuythisgame fine tune.....
# in total  111 examples
# rouge_1_average score: 0.15324304153530285 0.01048217096708311
# rouge_2_average score: 0.03935598369823732 0.006224549044090715
# rouge_l_average score: 0.12720907842028836 0.00851942381942551
# ukpolitics full tune.....
# in total  115 examples
# rouge_1_average score: 0.1089406292488092 0.010677241532224118
# rouge_2_average score: 0.02076121207138104 0.004451724076034679
# rouge_l_average score: 0.08922263459539301 0.008738577948335753
# ukpolitics fine tune.....
# in total  115 examples
# rouge_1_average score: 0.16010760226397 0.011310664679017675
# rouge_2_average score: 0.03204824871439657 0.006417625282269094
# rouge_l_average score: 0.121135270172636 0.008716117528589237
# Dogtraining full tune.....
# in total  119 examples
# rouge_1_average score: 0.1845668554166289 0.01118686231237222
# rouge_2_average score: 0.03405016756961451 0.0060720857134414965
# rouge_l_average score: 0.14091504220862633 0.008137244079052192
# Dogtraining fine tune.....
# in total  119 examples
# rouge_1_average score: 0.17776555040390754 0.012053598427009418
# rouge_2_average score: 0.037613593881531564 0.005940515122193253
# rouge_l_average score: 0.13054687298885234 0.008860282325930106
# AskHistorians full tune.....
# in total  117 examples
# rouge_1_average score: 0.1739321037161994 0.010922750447154309
# rouge_2_average score: 0.029430523441127714 0.004365738718138504
# rouge_l_average score: 0.12740644826317857 0.007906903050423155
# AskHistorians fine tune.....
# in total  117 examples
# rouge_1_average score: 0.18341561247867796 0.010614215176778161
# rouge_2_average score: 0.03232188146991062 0.00491897986569584
# rouge_l_average score: 0.13893393277588995 0.007567047161766682
# Anxiety full tune.....
# in total  118 examples
# rouge_1_average score: 0.16202177670117368 0.011000723629733174
# rouge_2_average score: 0.03364484052097254 0.006129207722779966
# rouge_l_average score: 0.12832525617512375 0.00860526349860465
# Anxiety fine tune.....
# in total  118 examples
# rouge_1_average score: 0.17283383249933215 0.012260234666016655
# rouge_2_average score: 0.045236671724206284 0.007667943042144181
# rouge_l_average score: 0.1348907156446666 0.009511546420662218

# %%
10, 0.15 'legaladvice', 'relationships', 'atheismbot', 'Anxiety', 'Dogtraining'
'nfl',  
'pettyrevenge',                 
'ShouldIbuythisgame', 'ukpolitics', 
'Dogtraining',  'AskHistorians',

# %%
subreddit_names = ['nfl']

for sub in subreddit_names:
    path_pre = './log/full_tune_' + sub + '_exp/'
    subfolder_name = [d for d in listdir(path_pre) if d[:3] == 'dec'][0]
    path_pre += subfolder_name
    print(sub, 'full tune.....')
    computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, print_result=True)
    
    path_pre = './log/fine_tune_' + sub + '_exp/'
    subfolder_name = [d for d in listdir(path_pre) if d[:3] == 'dec'][0]
    path_pre += subfolder_name
    print(sub, 'fine tune.....')
    computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, print_result=True)
# Out:
# nfl full tune.....
# in total  111 examples
# rouge_1_average score: 0.12638263057443752 0.011319843694947445
# rouge_2_average score: 0.01930612407612031 0.003672464106028462
# rouge_l_average score: 0.09360622753502848 0.007814780649662168
# nfl fine tune.....
# in total  100 examples
# rouge_1_average score: 0.13204170460653933 0.013291570146508133
# rouge_2_average score: 0.02936093705797179 0.007311172119205005
# rouge_l_average score: 0.1040351936509397 0.010111900226771936

# %%
# nfl 20 epoch, lr = 0.15 
rouge_1_average score: 0.12021826204483196 0.010603618436396062
rouge_2_average score: 0.017950863997786098 0.00335056566439929
rouge_l_average score: 0.08754095184195483 0.006666788393366648
nfl fine tune.....
in total  11 examples
rouge_1_average score: 0.1270158743248592 0.04137294472182874
rouge_2_average score: 0.03345022904373553 0.015619501381995185
rouge_l_average score: 0.106672302552716 0.030094482867594908
pettyrevenge full tune.....

# nfl 5 epoch, lr = 0.15 full loss ~3.2 fine loss ~ 4.9
nfl full tune.....
in total  111 examples
rouge_1_average score: 0.12638263057443752 0.011319843694947445
rouge_2_average score: 0.01930612407612031 0.003672464106028462
rouge_l_average score: 0.09360622753502848 0.007814780649662168
nfl fine tune.....
in total  100 examples
rouge_1_average score: 0.13204170460653933 0.013291570146508133
rouge_2_average score: 0.02936093705797179 0.007311172119205005
rouge_l_average score: 0.1040351936509397 0.010111900226771936

# nfl 5 epoch, lr = 0.5 baozha


# everything lr 0.075

# %%
# our model on 10_1000

path_pre = './log/load_word_emb_doc_vec_combine_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-2874_cov_init'

computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, print_result=True)
# computeRougeScore(path_pre, alpha_input = 0.99,  consider_first=1000,
#                   first_str_in_ref=200, ref_folder = '/content/', decode_folder = '/reference/')
# Out:
# in total  1165 examples
# rouge_1_average score: 0.12901878481620807
# rouge_2_average score: 0.03648754486113983
# rouge_l_average score: 0.11440320763401278
# [0.12901878481620807, 0.03648754486113983, 0.11440320763401278]

# %%
def make_decode_to_sub_mapping(story_list_dir, combined_decoded_dir, subreddit_names):

    text_file = open(story_list_dir, "r")
    story_file_list = [ l for l in text_file.read().split('\n')][:-1]
#     print(story_file_list)

    decoded_file_list =  [f.split('.')[0] for f in listdir(combined_decoded_dir) if isfile(join(combined_decoded_dir, f))]
    decoded_file_list.sort()
#     print(decoded_file_list)
    print(len(story_file_list), len(decoded_file_list))
    decode_to_sub_mapping = {}

    for sub in subreddit_names:
        for story_name, decode_name in zip(story_file_list, decoded_file_list):
            if sub in story_name:
                decode_to_sub_mapping[decode_name[:6]] = sub
    return decode_to_sub_mapping

# decoded_file_list.sort()

# %%
# doc vec individual performance

story_list_dir = '../processed_10_1k_mymodel/processed_combine_all/combine_test_list.txt'
combined_decoded_dir = './log/load_word_emb_doc_vec_combine_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-2874_cov_init/decoded'

subreddit_names = ['relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
                            'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

decode_to_sub_mapping = make_decode_to_sub_mapping(story_list_dir, combined_decoded_dir, subreddit_names)

path_pre = './log/load_word_emb_doc_vec_combine_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-2874_cov_init'

SubReddits_to_include_10 = [ 'relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
                            'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

for sub in SubReddits_to_include_10:
    print(sub, ' result::::::::::')
    computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, 
                  print_result=True, 
                 look_at_subred=sub, file_to_subred_mapping = decode_to_sub_mapping)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-86-8aac370e7498> in <module>
#       7                             'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']
#       8
# ----> 9 decode_to_sub_mapping = make_decode_to_sub_mapping(story_list_dir, combined_decoded_dir, subreddit_names)
#      10
#      11 path_pre = './log/load_word_emb_doc_vec_combine_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-2874_cov_init'
#
# <ipython-input-85-78e47395cb81> in make_decode_to_sub_mapping(story_list_dir, combined_decoded_dir, subreddit_names)
#       5 #     print(story_file_list)
#       6
# ----> 7     decoded_file_list =  [f.split('.')[0] for f in listdir(combined_decoded_dir) if isfile(join(combined_decoded_dir, f))]
#       8     decoded_file_list.sort()
#       9 #     print(decoded_file_list)
#
# FileNotFoundError: [Errno 2] No such file or directory: './log/load_word_emb_doc_vec_combine_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-2874_cov_init/decoded'

# %%
# pretrained individual performance

# story_list_dir = '../processed_10_1k_mymodel/processed_combine_all/combine_test_list.txt'
# combined_decoded_dir = './log/load_word_emb_doc_vec_combine_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-2874_cov_init/decoded'

# subreddit_names = ['relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
#                             'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

# decode_to_sub_mapping = make_decode_to_sub_mapping(story_list_dir, combined_decoded_dir, subreddit_names)

path_pre = './log/pretrained_combine_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238410_cov_init'

SubReddits_to_include_10 = [ 'relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
                            'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

for sub in SubReddits_to_include_10:
    print(sub, ' result::::::::::')
    computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, 
                  print_result=True, 
                 look_at_subred=sub, file_to_subred_mapping = decode_to_sub_mapping)
# Out:
# relationships  result::::::::::
# in total  118 examples
# rouge_1_average score: 0.15181866696846588 0.010595024766911395
# rouge_2_average score: 0.02619517711349942 0.004337470983586857
# rouge_l_average score: 0.11128027127476899 0.006964306253577916
# legaladvice  result::::::::::
# in total  118 examples
# rouge_1_average score: 0.17490754502651054 0.01036772803793547
# rouge_2_average score: 0.03166299879950671 0.004448565448039934
# rouge_l_average score: 0.12046043176770944 0.0065721492783617965
# nfl  result::::::::::
# in total  112 examples
# rouge_1_average score: 0.1457159720415128 0.011473075211480386
# rouge_2_average score: 0.027076644927859002 0.005547500212221864
# rouge_l_average score: 0.10329201982630518 0.007068364942554895
# pettyrevenge  result::::::::::
# in total  117 examples
# rouge_1_average score: 0.13771706319492488 0.010797396947147013
# rouge_2_average score: 0.020518930855500144 0.0036055045687485407
# rouge_l_average score: 0.09425813054158952 0.0063558550169160065
# atheismbot  result::::::::::
# in total  119 examples
# rouge_1_average score: 0.13540555396646942 0.00945553538604029
# rouge_2_average score: 0.02054653209599721 0.0036754648110041616
# rouge_l_average score: 0.092356679617998 0.005770206343917114
# ShouldIbuythisgame  result::::::::::
# in total  113 examples
# rouge_1_average score: 0.15108556845908588 0.010183689312660931
# rouge_2_average score: 0.027752579699665308 0.005014019920549298
# rouge_l_average score: 0.11112950414551762 0.0071487652157787036
# ukpolitics  result::::::::::
# in total  116 examples
# rouge_1_average score: 0.14280173986921657 0.009582179727579196
# rouge_2_average score: 0.023207573228655628 0.003639143638530472
# rouge_l_average score: 0.1024241632537474 0.006454941395840796
# Dogtraining  result::::::::::
# in total  119 examples
# rouge_1_average score: 0.16682584989865418 0.010487401550490244
# rouge_2_average score: 0.03200103108033159 0.004556462971784675
# rouge_l_average score: 0.11211275764769349 0.006554309681566524
# AskHistorians  result::::::::::
# in total  116 examples
# rouge_1_average score: 0.17006217615709782 0.009919169448877153
# rouge_2_average score: 0.02382342575438449 0.003936855059464431
# rouge_l_average score: 0.12144753967352737 0.006626570980659428
# Anxiety  result::::::::::
# in total  116 examples
# rouge_1_average score: 0.1484767360258762 0.009561571005519645
# rouge_2_average score: 0.02285898239845336 0.003691340530962116
# rouge_l_average score: 0.10539742396349402 0.006023666186784162

# %%
# pretrained + full tune individual performance

story_list_dir = '../processed_10_1k_mymodel/processed_combine_all/combine_test_list.txt'
combined_decoded_dir = './log/pretrained_combine10_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238410_cov_init/decoded'

subreddit_names = ['relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
                            'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

decode_to_sub_mapping = make_decode_to_sub_mapping(story_list_dir, combined_decoded_dir, subreddit_names)

path_pre = './log/full_tune_combine10_exp1/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238935_cov_init'

SubReddits_to_include_10 = [ 'relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
                            'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

for sub in SubReddits_to_include_10:
    print(sub, ' result::::::::::')
    computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, 
                  print_result=True, 
                 look_at_subred=sub, file_to_subred_mapping = decode_to_sub_mapping)
# Out:
# 1165 1164
# relationships  result::::::::::
# in total  118 examples
# rouge_1_average score: 0.16747786637877105 0.009992428303020663
# rouge_2_average score: 0.044792280658500216 0.006384090034850985
# rouge_l_average score: 0.13065851782327395 0.007614624946857973
# legaladvice  result::::::::::
# in total  118 examples
# rouge_1_average score: 0.17562520179089763 0.010150270917342623
# rouge_2_average score: 0.03069462487682585 0.005844308586058039
# rouge_l_average score: 0.1330796949302635 0.007653497440504797
# nfl  result::::::::::
# in total  112 examples
# rouge_1_average score: 0.11713403799846722 0.009828335887342814
# rouge_2_average score: 0.015269840291269684 0.003567092782029576
# rouge_l_average score: 0.09296354434258679 0.00719032873266359
# pettyrevenge  result::::::::::
# in total  117 examples
# rouge_1_average score: 0.11813778869329875 0.009125228735359349
# rouge_2_average score: 0.017493332663350708 0.004799438109558498
# rouge_l_average score: 0.09410584638987399 0.006641200249629769
# atheismbot  result::::::::::
# in total  119 examples
# rouge_1_average score: 0.2521398971093077 0.013598981650668949
# rouge_2_average score: 0.14671889294216586 0.012477077247567735
# rouge_l_average score: 0.23515191524991186 0.012858311913512282
# ShouldIbuythisgame  result::::::::::
# in total  113 examples
# rouge_1_average score: 0.14592624944211655 0.012479700369383619
# rouge_2_average score: 0.03487852813153023 0.006953014011966911
# rouge_l_average score: 0.12284648470161155 0.009995847090804533
# ukpolitics  result::::::::::
# in total  116 examples
# rouge_1_average score: 0.14285733021368038 0.010425421117720653
# rouge_2_average score: 0.025971301455803137 0.004614483916758989
# rouge_l_average score: 0.11151245783034774 0.00817182485639447
# Dogtraining  result::::::::::
# in total  119 examples
# rouge_1_average score: 0.15844667205823884 0.010953016590405203
# rouge_2_average score: 0.034766345666597684 0.005861912033120258
# rouge_l_average score: 0.12382001959429169 0.008602476918154443
# AskHistorians  result::::::::::
# in total  116 examples
# rouge_1_average score: 0.15863285995217039 0.010739711747353777
# rouge_2_average score: 0.025447457075615163 0.004572477996890133
# rouge_l_average score: 0.12488463778027621 0.00840704381718055
# Anxiety  result::::::::::
# in total  116 examples
# rouge_1_average score: 0.14398159155676166 0.011009896850493776
# rouge_2_average score: 0.03371230884566536 0.006161099088207049
# rouge_l_average score: 0.11633569694231047 0.008406842655276957

# %%
decode_to_sub_mappingx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-390d8fcdbbd6> in <module>
# ----> 1 decode_to_sub_mapping
#
# NameError: name 'decode_to_sub_mapping' is not defined

# %%
# pretrained + fine tune individual performance

story_list_dir = '../processed_10_1k_mymodel/processed_combine_all/combine_test_list.txt'
combined_decoded_dir = './log/pretrained_combine10_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238410_cov_init/decoded'

subreddit_names = ['relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
                            'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

decode_to_sub_mapping = make_decode_to_sub_mapping(story_list_dir, combined_decoded_dir, subreddit_names)

path_pre = './log/fine_tune_combine10_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238937_cov_init'

SubReddits_to_include_10 = [ 'relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
                            'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

for sub in SubReddits_to_include_10:
    print(sub, ' result::::::::::')
    computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, 
                  print_result=True, 
                 look_at_subred=sub, file_to_subred_mapping = decode_to_sub_mapping)
# Out:
# 1165 1164
# relationships  result::::::::::
# in total  118 examples
# rouge_1_average score: 0.19196453924709567 0.011163465198484568
# rouge_2_average score: 0.057678325761009334 0.008413502012566649
# rouge_l_average score: 0.1540822478521103 0.009235407101931261
# legaladvice  result::::::::::
# in total  118 examples
# rouge_1_average score: 0.20424437038346138 0.012120571864832917
# rouge_2_average score: 0.0503355880782874 0.00644247611309522
# rouge_l_average score: 0.15060310727120327 0.00862950631906692
# nfl  result::::::::::
# in total  112 examples
# rouge_1_average score: 0.1409078450617655 0.011150248323476556
# rouge_2_average score: 0.0260616038221032 0.005334460680611207
# rouge_l_average score: 0.10720575594481106 0.008098381760252422
# pettyrevenge  result::::::::::
# in total  117 examples
# rouge_1_average score: 0.1389733501914467 0.011303480562090795
# rouge_2_average score: 0.026058889953165836 0.005544292572290207
# rouge_l_average score: 0.10344459863117823 0.008143718689209326
# atheismbot  result::::::::::
# in total  119 examples
# rouge_1_average score: 0.12905199147732135 0.011882622660492285
# rouge_2_average score: 0.028129497526688536 0.005759726738154199
# rouge_l_average score: 0.10379559309744474 0.009503908978644518
# ShouldIbuythisgame  result::::::::::
# in total  113 examples
# rouge_1_average score: 0.15685903318738426 0.01028353052341011
# rouge_2_average score: 0.03346574199335996 0.005876714940662787
# rouge_l_average score: 0.12250746351566341 0.007948177281226201
# ukpolitics  result::::::::::
# in total  116 examples
# rouge_1_average score: 0.1520411795177212 0.011037907510158198
# rouge_2_average score: 0.028021042213278436 0.004684097262918511
# rouge_l_average score: 0.11510084075137945 0.00806938353265201
# Dogtraining  result::::::::::
# in total  119 examples
# rouge_1_average score: 0.1856265958628495 0.012633594776101662
# rouge_2_average score: 0.045920849046921654 0.007831633542340713
# rouge_l_average score: 0.1352043993143356 0.008971864236554182
# AskHistorians  result::::::::::
# in total  116 examples
# rouge_1_average score: 0.1690771964916491 0.010669590524593302
# rouge_2_average score: 0.033077842924889335 0.004965344701479845
# rouge_l_average score: 0.129733382149594 0.008461436804050575
# Anxiety  result::::::::::
# in total  116 examples
# rouge_1_average score: 0.16244389447313617 0.013153902165806195
# rouge_2_average score: 0.03848216173359528 0.0069807054509641395
# rouge_l_average score: 0.12797452821697788 0.009694688756120905

# %%
# pretrained + fine tune precision

story_list_dir = '../processed_10_1k_mymodel/processed_combine_all/combine_test_list.txt'
combined_decoded_dir = './log/pretrained_combine10_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238410_cov_init/decoded'

subreddit_names = ['relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
                            'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

decode_to_sub_mapping = make_decode_to_sub_mapping(story_list_dir, combined_decoded_dir, subreddit_names)

path_pre = './log/fine_tune_combine10_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238937_cov_init'

SubReddits_to_include_10 = [ 'relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
                            'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

for sub in SubReddits_to_include_10:
    print(sub, ' result::::::::::')
    computeRougeScore(path_pre, alpha_input = 0.99,if_rouge_be=False, consider_first=0, 
                  random_test=False, print_result=True,
                      look_at_subred=sub,file_to_subred_mapping = decode_to_sub_mapping,
                  ref_folder = '/content/', decode_folder = '/decoded/')
# Out:
# 1165 1164
# relationships  result::::::::::
# in total  118 examples
# rouge_1_average score: 0.785762269699042 0.016354077032896208
# rouge_2_average score: 0.600278306376214 0.02393838515812059
# rouge_l_average score: 0.6641072466025687 0.01780900507728175
# legaladvice  result::::::::::
# in total  118 examples
# rouge_1_average score: 0.8342094055226156 0.014233613061576661
# rouge_2_average score: 0.6836840164251315 0.021698086753062007
# rouge_l_average score: 0.723200655278665 0.017953420856529286
# nfl  result::::::::::
# in total  112 examples
# rouge_1_average score: 0.7927059217730671 0.0203484982965305
# rouge_2_average score: 0.6441983180818772 0.02961875730139684
# rouge_l_average score: 0.6883470894552293 0.02308026145753726
# pettyrevenge  result::::::::::
# in total  117 examples
# rouge_1_average score: 0.737222395848226 0.022585126776182313
# rouge_2_average score: 0.5438533894149981 0.031877077638662855
# rouge_l_average score: 0.6294840273324057 0.02200130073138308
# atheismbot  result::::::::::
# in total  119 examples
# rouge_1_average score: 0.7172878878761074 0.024011900130504495
# rouge_2_average score: 0.545620684788816 0.029721681561836386
# rouge_l_average score: 0.5992424145080106 0.02321517888421486
# ShouldIbuythisgame  result::::::::::
# in total  113 examples
# rouge_1_average score: 0.7888756720892868 0.01751959980760298
# rouge_2_average score: 0.600703669474752 0.025863796360384973
# rouge_l_average score: 0.671466821030122 0.02070383198511455
# ukpolitics  result::::::::::
# in total  116 examples
# rouge_1_average score: 0.8178604622958235 0.01641727333615654
# rouge_2_average score: 0.6428412368981116 0.02647330170257778
# rouge_l_average score: 0.7020669672075995 0.021875047749583366
# Dogtraining  result::::::::::
# in total  119 examples
# rouge_1_average score: 0.8018605503478707 0.01831375167761297
# rouge_2_average score: 0.6407186517514085 0.026488928141327427
# rouge_l_average score: 0.6972036683342289 0.020378080187850728
# AskHistorians  result::::::::::
# in total  116 examples
# rouge_1_average score: 0.7783139729010135 0.024324724575613896
# rouge_2_average score: 0.6100239064092131 0.03228883170893093
# rouge_l_average score: 0.6657957575195242 0.025473402023680404
# Anxiety  result::::::::::
# in total  116 examples
# rouge_1_average score: 0.7365411061493197 0.021028622414742716
# rouge_2_average score: 0.5330640897608719 0.03121836053072934
# rouge_l_average score: 0.617073166007183 0.01975364639253231

# %%
# print the precision full tune and fine tune result for each subreddit, 10 epoch

# subreddit_names = ['relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
#                             'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

subreddit_names = ['legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
                            'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

# subreddit_names = ['nfl']

for sub in subreddit_names:
#     path_pre = './log/full_tune_' + sub + '_exp/'
#     subfolder_name = [d for d in listdir(path_pre) if d[:3] == 'dec'][0]
#     path_pre += subfolder_name
#     print(sub, 'full tune.....')
#     computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, print_result=True)
    
    path_pre = './log/fine_tune_' + sub + '_exp/'
    subfolder_name = [d for d in listdir(path_pre) if d[:3] == 'dec'][0]
    path_pre += subfolder_name
    print(sub, 'fine tune.....')
    computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, print_result=True)

# %%
# print the lead-2/3 results

path_pre = '/home/ubuntu/cs224u/pointer/log/baseline-comebine_all_lead2/'

SubReddits_to_include_10 = [ 'relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
                            'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

for sub in SubReddits_to_include_10:
    print(sub, ' result::::::::::')
    computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, 
                  print_result=True, 
                 look_at_subred=sub, file_to_subred_mapping = decode_to_sub_mapping)
# Out:
# relationships  result::::::::::
# in total  119 examples
# rouge_1_average score: 0.15040356621771278
# rouge_2_average score: 0.025202959855291487
# rouge_l_average score: 0.10873971812008684
# legaladvice  result::::::::::
# in total  118 examples
# rouge_1_average score: 0.15863028452902894
# rouge_2_average score: 0.02933248383763507
# rouge_l_average score: 0.1080298889458904
# nfl  result::::::::::
# in total  111 examples
# rouge_1_average score: 0.15871224048227087
# rouge_2_average score: 0.027221915886211274
# rouge_l_average score: 0.11207939137194388
# pettyrevenge  result::::::::::
# in total  117 examples
# rouge_1_average score: 0.14804059298148514
# rouge_2_average score: 0.026215382377625728
# rouge_l_average score: 0.10179465680638504
# atheismbot  result::::::::::
# in total  119 examples
# rouge_1_average score: 0.16224971563912854
# rouge_2_average score: 0.032376212883578885
# rouge_l_average score: 0.11649625140352397
# ShouldIbuythisgame  result::::::::::
# in total  111 examples
# rouge_1_average score: 0.13872857406379258
# rouge_2_average score: 0.02609585732483627
# rouge_l_average score: 0.09833255303324746
# ukpolitics  result::::::::::
# in total  115 examples
# rouge_1_average score: 0.15513687368243434
# rouge_2_average score: 0.027020731058464635
# rouge_l_average score: 0.10587261666705397
# Dogtraining  result::::::::::
# in total  119 examples
# rouge_1_average score: 0.15538226375984232
# rouge_2_average score: 0.02950963994833494
# rouge_l_average score: 0.10844737429820861
# AskHistorians  result::::::::::
# in total  117 examples
# rouge_1_average score: 0.14266789013006165
# rouge_2_average score: 0.03192839531123992
# rouge_l_average score: 0.10145652267756067
# Anxiety  result::::::::::
# in total  118 examples
# rouge_1_average score: 0.173073955238508
# rouge_2_average score: 0.032973620646061234
# rouge_l_average score: 0.12026813284721645

# %%
# print the lead-2/3 results

path_pre = '/home/ubuntu/cs224u/pointer/log/baseline-comebine_all_lead3/'

SubReddits_to_include_10 = [ 'relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
                            'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

for sub in SubReddits_to_include_10:
    print(sub, ' result::::::::::')
    computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, 
                  print_result=True, 
                 look_at_subred=sub, file_to_subred_mapping = decode_to_sub_mapping)
# Out:
# relationships  result::::::::::
# in total  119 examples
# rouge_1_average score: 0.15850538413733006
# rouge_2_average score: 0.02473623626526117
# rouge_l_average score: 0.10991903290275977
# legaladvice  result::::::::::
# in total  118 examples
# rouge_1_average score: 0.1773223556835235
# rouge_2_average score: 0.03084239317407503
# rouge_l_average score: 0.11304612337378775
# nfl  result::::::::::
# in total  111 examples
# rouge_1_average score: 0.1713479915001112
# rouge_2_average score: 0.030215757477078227
# rouge_l_average score: 0.11629813166433371
# pettyrevenge  result::::::::::
# in total  117 examples
# rouge_1_average score: 0.16588169706078407
# rouge_2_average score: 0.030900425453985882
# rouge_l_average score: 0.1110201885350039
# atheismbot  result::::::::::
# in total  119 examples
# rouge_1_average score: 0.1764058467899222
# rouge_2_average score: 0.03672801879786728
# rouge_l_average score: 0.12378297509035283
# ShouldIbuythisgame  result::::::::::
# in total  111 examples
# rouge_1_average score: 0.1595052591407454
# rouge_2_average score: 0.030717027664017037
# rouge_l_average score: 0.10918286356027262
# ukpolitics  result::::::::::
# in total  115 examples
# rouge_1_average score: 0.17878898050729497
# rouge_2_average score: 0.031229415219196945
# rouge_l_average score: 0.11744490958103292
# Dogtraining  result::::::::::
# in total  119 examples
# rouge_1_average score: 0.17148499998032685
# rouge_2_average score: 0.032552089589544295
# rouge_l_average score: 0.1167185841734324
# AskHistorians  result::::::::::
# in total  117 examples
# rouge_1_average score: 0.15733767183840827
# rouge_2_average score: 0.031628151945396026
# rouge_l_average score: 0.1076436821384361
# Anxiety  result::::::::::
# in total  118 examples
# rouge_1_average score: 0.18124919203142276
# rouge_2_average score: 0.03500458918049781
# rouge_l_average score: 0.11840220134934046

# %%
# print the individual training and together training

SubReddits_to_include_10 = ['combine_all', 'relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
                            'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']
# exp_folder_dir = '/decode_test_400maxenc_4beam_10mindec_120maxdec_ckpt-1757_cov_init'

for sub in SubReddits_to_include_10:
    print(sub,'result:::::::::')
    ref_path = '/home/ubuntu/cs224u/pointer/log/' + sub + '_exp'
    sub_folder = [f for f in listdir(ref_path) if f[0] == 'd'][0]
    path_pre = '/home/ubuntu/cs224u/pointer/log/' + sub + '_exp/' + sub_folder
    computeRougeScore(path_pre,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, print_result=True)
# Out:
# combine_all result:::::::::
# in total  1164 examples
# rouge_1_average score: 0.15817978453330553
# rouge_2_average score: 0.038528688508180406
# rouge_l_average score: 0.13266524343571767
# relationships result:::::::::
# in total  119 examples
# rouge_1_average score: 0.12525299019225103
# rouge_2_average score: 0.025543781534426203
# rouge_l_average score: 0.112095598052901
# legaladvice result:::::::::
# in total  118 examples
# rouge_1_average score: 0.01720943504730226
# rouge_2_average score: 0.0007093199920169055
# rouge_l_average score: 0.015630173986726795
# nfl result:::::::::
# in total  111 examples
# rouge_1_average score: 0.027012105816404664
# rouge_2_average score: 0.006144794518875825
# rouge_l_average score: 0.025154912207059177
# pettyrevenge result:::::::::
# in total  117 examples
# rouge_1_average score: 0.07683100233448827
# rouge_2_average score: 0.027478386869204337
# rouge_l_average score: 0.07539629782783977
# atheismbot result:::::::::
# in total  119 examples
# rouge_1_average score: 0.1704642067002566
# rouge_2_average score: 0.08164719430292318
# rouge_l_average score: 0.1521278414283474
# ShouldIbuythisgame result:::::::::
# in total  111 examples
# rouge_1_average score: 0.10223104556569558
# rouge_2_average score: 0.0041087641363249895
# rouge_l_average score: 0.0860155325152653
# ukpolitics result:::::::::
# in total  115 examples
# rouge_1_average score: 0.033739787644274204
# rouge_2_average score: 0.00012882447665056362
# rouge_l_average score: 0.03180999097455697
# Dogtraining result:::::::::
# in total  119 examples
# rouge_1_average score: 0.1543734982069903
# rouge_2_average score: 0.014079800518490929
# rouge_l_average score: 0.13668641658235928
# AskHistorians result:::::::::
# in total  117 examples
# rouge_1_average score: 0.08273060441330628
# rouge_2_average score: 0.00044984255510571296
# rouge_l_average score: 0.08191779163066297
# Anxiety result:::::::::
# in total  118 examples
# rouge_1_average score: 0.0904094495849223
# rouge_2_average score: 0.01032621380843723
# rouge_l_average score: 0.07605499432429981

# %%
# print the result of hyper-para searching
ref_path = '/home/ubuntu/cs224u/pointer/log/'
sub_folder = [f for f in listdir(ref_path) if 'fine_tune_exp_hidden' in f]
for folder in sub_folder:
    look_path = ref_path + folder
    try:
        exp_para_name = [f for f in listdir(look_path) if 'decode' in f][0]
        path = look_path + '/' + exp_para_name
        print(folder)
        computeRougeScore(path,alpha_input = 0.5,  if_rouge_be=False, consider_first=0, random_test=False, print_result=True)
    except:
        print('!!!!no', folder)
# Out:
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_50_min_dec_steps_20_lr_0.03
# in total  1164 examples
# rouge_1_average score: 0.06029066446085742
# rouge_2_average score: 0.0003217797716831448
# rouge_l_average score: 0.05886041827459867
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_100_min_dec_steps_10_lr_0.03
# in total  1164 examples
# rouge_1_average score: 0.012944424411662075
# rouge_2_average score: 0.0
# rouge_l_average score: 0.012944424411662075
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_100_min_dec_steps_10_lr_0.3
# in total  1164 examples
# rouge_1_average score: 0.11260193583562358
# rouge_2_average score: 0.025486343518514868
# rouge_l_average score: 0.10215226619675451
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_50_min_dec_steps_20_lr_0.5
# in total  1164 examples
# rouge_1_average score: 0.14413197791721605
# rouge_2_average score: 0.02160925474391756
# rouge_l_average score: 0.11393097098653841
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_100_min_dec_steps_10_lr_0.05
# in total  1164 examples
# rouge_1_average score: 0.011057346180310491
# rouge_2_average score: 0.0
# rouge_l_average score: 0.010796459618736643
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_100_min_dec_steps_20_lr_0.5
# in total  1164 examples
# rouge_1_average score: 0.12887519855628374
# rouge_2_average score: 0.016384054643072833
# rouge_l_average score: 0.10972576912815489
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_50_min_dec_steps_10_lr_0.5
# in total  1164 examples
# rouge_1_average score: 0.14200238453541042
# rouge_2_average score: 0.020782177843411877
# rouge_l_average score: 0.12145665604721051
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_100_min_dec_steps_20_lr_0.03
# in total  1164 examples
# rouge_1_average score: 0.002812553145498518
# rouge_2_average score: 0.0
# rouge_l_average score: 0.002812553145498518
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_50_min_dec_steps_20_lr_0.1
# in total  1164 examples
# rouge_1_average score: 0.07199256500395587
# rouge_2_average score: 0.0008854524702003964
# rouge_l_average score: 0.0665828104074964
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_100_min_dec_steps_10_lr_0.5
# in total  1164 examples
# rouge_1_average score: 0.10441177412097861
# rouge_2_average score: 0.016691978193055363
# rouge_l_average score: 0.08677128772805069
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_100_min_dec_steps_20_lr_0.1
# in total  1164 examples
# rouge_1_average score: 0.03674124574934153
# rouge_2_average score: 0.0037001553294744288
# rouge_l_average score: 0.03553336466369825
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_100_min_dec_steps_20_lr_0.3
# in total  1164 examples
# rouge_1_average score: 0.11748067196052016
# rouge_2_average score: 0.0215134767468136
# rouge_l_average score: 0.09637473253784466
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_100_min_dec_steps_10_lr_0.1
# in total  1164 examples
# rouge_1_average score: 0.08288416169165094
# rouge_2_average score: 0.0002447498025327016
# rouge_l_average score: 0.07759740738859679
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_50_min_dec_steps_20_lr_0.3
# in total  1164 examples
# rouge_1_average score: 0.1010426058074482
# rouge_2_average score: 0.020035920598758167
# rouge_l_average score: 0.08658830873759826
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_50_min_dec_steps_10_lr_0.03
# in total  1164 examples
# rouge_1_average score: 0.000838751774155156
# rouge_2_average score: 0.0
# rouge_l_average score: 0.000838751774155156
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_100_min_dec_steps_20_lr_0.05
# in total  1164 examples
# rouge_1_average score: 0.0694314768060981
# rouge_2_average score: 0.0003269671177021417
# rouge_l_average score: 0.06715158291658349
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_50_min_dec_steps_10_lr_0.05
# in total  1164 examples
# rouge_1_average score: 0.06639854173664902
# rouge_2_average score: 0.00014081282700521635
# rouge_l_average score: 0.06260460930861143
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_50_min_dec_steps_10_lr_0.1
# in total  1164 examples
# rouge_1_average score: 0.04490252514311162
# rouge_2_average score: 0.0002291664288187904
# rouge_l_average score: 0.043730977375096694
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_50_min_dec_steps_10_lr_0.3
# in total  1164 examples
# rouge_1_average score: 0.075370486715865
# rouge_2_average score: 0.010182998983837612
# rouge_l_average score: 0.0621818845018397
# fine_tune_exp_hidden_64_emb_32_batch_16_max_enc_steps_300_max_dec_steps_50_min_dec_steps_20_lr_0.05
# in total  1164 examples
# rouge_1_average score: 0.07470373876686343
# rouge_2_average score: 0.0004014732782779418
# rouge_l_average score: 0.07037118475475111

# %%
ref_path = '/home/ubuntu/cs224u/pointer/log/' + sub + '_exp'
[f for f in listdir(ref_path) if f[0] == 'd']
# Out:
# ['decode_test_400maxenc_4beam_10mindec_120maxdec_ckpt-1757_cov_init']

# %%
computeRougeScore(path_pre, alpha_input = 0.99,if_rouge_be=False, consider_first=2000, 
                  random_test=True, print_result=True,
                  ref_folder = '/content/', decode_folder = '/decoded/')
# Out:
# in total  2000 examples
# rouge_1_average score: 0.7444281817937951
# rouge_2_average score: 0.5003590780151564
# rouge_l_average score: 0.5965231043409077
# [0.7444281817937951, 0.5003590780151564, 0.5965231043409077]

# %%
def plot_coverage(path_pre, consider_first, random_test = False, ref_folder = '/content/', 
                  decode_folder = '/reference/', print_progress = True):
    str_length = [i *0.1 for i in range(1, 11)]
    r_scores_ref = np.zeros([3, len(str_length)])
    r_scores_dec = np.zeros([3, len(str_length)])
    max_scores_ref = computeRougeScore(path_pre, alpha_input = 0.99,  consider_first=consider_first,
                      first_str_in_ref=50000, random_test = random_test, 
                                       ref_folder = '/content/', decode_folder = '/reference/')
    max_scores_dec = computeRougeScore(path_pre, alpha_input = 0.99,  consider_first=consider_first,
                      first_str_in_ref=50000, random_test = random_test, 
                                       ref_folder = '/content/', decode_folder = '/decoded/')
    for i, s in enumerate(str_length):
        if print_progress:
            print('calculating ', i ,'/', len(str_length))
        r_scores_ref[:, i]= computeRougeScore(path_pre, alpha_input = 0.99,  consider_first=consider_first,
                      first_str_in_ref=s, random_test = random_test, 
                                              ref_folder = '/content/', decode_folder = '/reference/')
        r_scores_dec[:, i]= computeRougeScore(path_pre, alpha_input = 0.99,  consider_first=consider_first,
                      first_str_in_ref=s, random_test = random_test, 
                                              ref_folder = '/content/', decode_folder = '/decoded/')
    #     r1_scores[0, i] = r1
    r_scores_ref = r_scores_ref / np.array(max_scores_ref).reshape([3,1])
    r_scores_dec = r_scores_dec / np.array(max_scores_dec).reshape([3,1])
    
    labels = ['rouge1', 'rouge2', 'rougel']
    colors = ['red', 'green', 'blue']
    for i in range(3):
        plt.plot([0] + str_length, [0] + list(r_scores_ref[i]), color = colors[i], label = labels[i] + '_ref')
        plt.plot([0] + str_length, [0] + list(r_scores_dec[i]), color = colors[i], ls = '--', label = labels[i] + '_dec')
    plt.xlabel('Content Ratio')
    plt.ylabel('Precision Ratio')
    plt.legend()
    plt.show()

# %%
# pretrained on relationships

path_pre = './log/pretrained_relationships_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238410_cov_init_cov_init'

consider_first = 100

plot_coverage(path_pre, consider_first)
# Out:
# calculating  0 / 10
# calculating  1 / 10
# calculating  2 / 10
# calculating  3 / 10
# calculating  4 / 10
# calculating  5 / 10
# calculating  6 / 10
# calculating  7 / 10
# calculating  8 / 10
# calculating  9 / 10

# %%
# fine-tuned on relationships

path_pre = './log/pretrained_fine_tune_relationships_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238949_cov_init'

consider_first = 100

plot_coverage(path_pre, consider_first)
# Out:
# calculating  0 / 10
# calculating  1 / 10
# calculating  2 / 10
# calculating  3 / 10
# calculating  4 / 10
# calculating  5 / 10
# calculating  6 / 10
# calculating  7 / 10
# calculating  8 / 10
# calculating  9 / 10

# %%
# post-trained on relationships

path_pre = './log/pretrained_full_tune_relationships_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238965_cov_init'

consider_first = 100

plot_coverage(path_pre, consider_first)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-d4fcd119dd35> in <module>
#       5 consider_first = 100
#       6
# ----> 7 plot_coverage(path_pre, consider_first)
#
# <ipython-input-22-1d5c2e3870cd> in plot_coverage(path_pre, consider_first, random_test, ref_folder, decode_folder)
#       5     max_scores_ref = computeRougeScore(path_pre, alpha_input = 0.99,  consider_first=consider_first,
#       6                       first_str_in_ref=50000, random_test = random_test,
# ----> 7                                        ref_folder = '/content/', decode_folder = '/reference/')
#       8     max_scores_dec = computeRougeScore(path_pre, alpha_input = 0.99,  consider_first=consider_first,
#       9                       first_str_in_ref=50000, random_test = random_test,
#
# <ipython-input-2-678f6580587b> in computeRougeScore(path_pre, alpha_input, consider_first, if_rouge_be, random_test, first_str_in_ref, print_progress, print_result, confidence_level, ref_folder, decode_folder, look_at_subred, file_to_subred_mapping)
#      22         #decoded_files = decoded_files[:5000]: to deal with the large AskReddit Dataset
#      23     else:
# ---> 24         reference_files = [f for f in listdir(ref_path) if isfile(join(ref_path, f))]
#      25         reference_files.sort()
#      26         #reference_files = reference_files[:5000]: to deal with the large AskReddit Dataset
#
# FileNotFoundError: [Errno 2] No such file or directory: './log/pretrained_full_tune_relationships_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238965_cov_init/content/'

# %%
# SubReddits_to_include_10 = [ 'relationships', 'legaladvice', 'nfl',  'pettyrevenge', 'atheismbot', 
#                             'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']

SubReddits_to_include_9 = [ 'legaladvice',  'pettyrevenge', 'atheismbot', 
                            'ShouldIbuythisgame', 'ukpolitics', 'Dogtraining',  'AskHistorians', 'Anxiety']
for sub in SubReddits_to_include_9:
    consider_first = 100
    path_pre = './log/full_tune_' + sub + '_exp/'
    subfolder_name = [d for d in listdir(path_pre) if d[:3] == 'dec'][0]
    path_pre += subfolder_name
    print(sub, 'full tune.....')
    plot_coverage(path_pre, consider_first, print_progress=False)

    path_pre = './log/fine_tune_' + sub + '_exp/'
    subfolder_name = [d for d in listdir(path_pre) if d[:3] == 'dec'][0]
    path_pre += subfolder_name
    print(sub, 'fine tune.....')
    plot_coverage(path_pre, consider_first, print_progress=False)
# Out:
# legaladvice full tune.....
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
# legaladvice fine tune.....
# pettyrevenge full tune.....
# pettyrevenge fine tune.....
# atheismbot full tune.....
# atheismbot fine tune.....
# ShouldIbuythisgame full tune.....
# ShouldIbuythisgame fine tune.....
# ukpolitics full tune.....
# ukpolitics fine tune.....
# Dogtraining full tune.....
# Dogtraining fine tune.....
# AskHistorians full tune.....
# AskHistorians fine tune.....
# Anxiety full tune.....
# Anxiety fine tune.....

# %%
path_pre = './log/pretrained_relationships_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238410_cov_init_cov_init'


computeRougeScore(path_pre, alpha_input = 0.99,if_rouge_be=False, consider_first=0, 
                  random_test=False, print_result=True,
                  ref_folder = '/content/', decode_folder = '/decoded/')
# Out:
# in total  119 examples
# rouge_1_average score: 0.8091868861167498 0.017092933666024813
# rouge_2_average score: 0.6733459317198187 0.02503745808413999
# rouge_l_average score: 0.7038896048762723 0.021113249948246374
# [0.8091868861167498, 0.6733459317198187, 0.7038896048762723]

# %%
path_pre = './log/pretrained_fine_tune_relationships_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238949_cov_init'

computeRougeScore(path_pre, alpha_input = 0.99,if_rouge_be=False, consider_first=0, 
                  random_test=False, print_result=True,
                  ref_folder = '/content/', decode_folder = '/decoded/')
# Out:
# in total  119 examples
# rouge_1_average score: 0.8036653501884097 0.014006098537809495
# rouge_2_average score: 0.5894227950840422 0.01855553795225298
# rouge_l_average score: 0.6535280209219695 0.015972314779256966
# [0.8036653501884097, 0.5894227950840422, 0.6535280209219695]

# %%
path_pre = './log/pretrained_full_tune_relationships_exp/decode_test_400maxenc_4beam_35mindec_120maxdec_ckpt-238965_cov_init'

computeRougeScore(path_pre, alpha_input = 0.99,if_rouge_be=False, consider_first=0, 
                  random_test=False, print_result=True,
                  ref_folder = '/content/', decode_folder = '/decoded/')
# Out:
# in total  119 examples
# rouge_1_average score: 0.7795098754782164 0.01523345490209016
# rouge_2_average score: 0.571110692303556 0.02303263564119674
# rouge_l_average score: 0.6380787154730433 0.016848408166735104
# [0.7795098754782164, 0.571110692303556, 0.6380787154730433]

# %%
result of pretrained on relationships: first 5000 samples
# precision of decoded vs content
rouge_1_average score: 0.9476733773189917
rouge_2_average score: 0.8781008312357037
rouge_l_average score: 0.7871324912436809
    
# precision of reference vs content
rouge_1_average score: 0.6247194098851112
rouge_2_average score: 0.22893374806623992
rouge_l_average score: 0.44880102949302747

# rouge score of decoded vs reference 
rouge_1_average score: 0.20083441528699159
rouge_2_average score: 0.04273009170748925
rouge_l_average score: 0.12879304116662274
    
# rouge score of docoded vs reference (reddit-trained, 2000 examples)    
rouge_1_average score: 0.22215900752330625
rouge_2_average score: 0.0698998361164686
rouge_l_average score: 0.17615150345659464
    
# rouge score of docoded vs reference (reddit-fine-tuned, 2000 examples)    
rouge_1_average score: 0.21079686760037958
rouge_2_average score: 0.06482064476960846
rouge_l_average score: 0.16468544256901335
    
    
    
# on relationships, big 
# precision of decoded vs content (pre-trained, 2000 examples)
rouge_1_average score: 0.9476733773189917
rouge_2_average score: 0.8781008312357037
rouge_l_average score: 0.7871324912436809
    
# precision score of docoded vs content (reddit-fine-tuned, 2000 examples)        
rouge_1_average score: 0.7444281817937951
rouge_2_average score: 0.5003590780151564
rouge_l_average score: 0.5965231043409077

# precision of docoded vs content (reddit-trained, 2000 examples)    
rouge_1_average score: 0.8049491511060715
rouge_2_average score: 0.6190002024114848
rouge_l_average score: 0.6827285338828178

# %%
# the pointer model v.s. our model
# orginal
rouge_1_average score: 0.15817978453330553
rouge_2_average score: 0.038528688508180406
rouge_l_average score: 0.13266524343571767
    
# our model    
rouge_1_average score: 0.1285903161542736
rouge_2_average score: 0.024403407513581533
rouge_l_average score: 0.10796030216648057

# %% [markdown]
# # not relavant below
